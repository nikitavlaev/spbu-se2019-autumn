# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import random
def generate_input_file(size):
  outfile = open("/content/drive/My Drive/Colab Notebooks/input.txt", "w")

  print(size, file=outfile, end=" ")

  for i in range(size):
      print(random.randint(-10000, 10000), file=outfile, end=" ")

  print("", file=outfile)
  outfile.close()

# %%
# !cd /content/drive/'My Drive'/'Colab Notebooks'/ && nvcc main.cu -o main 
generate_input_file(100000)
# !cd /content/drive/'My Drive'/'Colab Notebooks'/ && ./main input.txt s && ./main input.txt p
# Out:
# Time: 0.0660524s, 100000 elements
# Time: 0.0115187s, 100000 elements

# %%
# !ls "/content/drive/My Drive/Colab Notebooks/"
# Out:
# deploy.ipynb  input.txt  main  main.cu	makefile.mk  Task06.ipynb

# %%
import random
sz = 16
outfile = open("/content/drive/My Drive/Colab Notebooks/input.txt", "w")

print(sz, file=outfile, end=" ")

for i in range(sz):
    print(random.randint(-100, 100), file=outfile, end=" ")

print("", file=outfile)
outfile.close()

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.collections import EventCollection
import numpy as np

results_data = np.array([[20, 0.0000099, 0.0078122], 
                            [100, 0.0000386, 0.0078226], 
                            [1000, 0.0002943, 0.0082565], 
                            [10000, 0.0054733, 0.009326], 
                            [100000, 0.045529, 0.0115187], 
                            [1000000, 0.752112, 0.0317107], 
                            [2000000, 1.6113, 0.0527717],
                            [4000000, 3.43647, 0.0923133]])
                      

matplotlib.rcParams.update({'font.size': 14})
fig = plt.figure(figsize=(10,5))
fig.subplots_adjust(top=2)
subplt = fig.add_subplot(211)

plt.yscale('log')
plt.xscale('linear')
subplt.plot(results_data[:, 0], results_data[:, 1], color='blue', label='CPU', linewidth=2)
subplt.plot(results_data[:, 0], results_data[:, 2], color='olive', label='GPU', linewidth=2)
subplt.set_xlabel('Size of array')
subplt.set_ylabel('Time (s)')

plt.title('Bitonic sort, 20 experiments averaged')
plt.legend()
plt.show()
